# %%
import pandas as pd
import matplotlib.pyplot as  plt
import seaborn as sns
import numpy as np

# %%
df= pd.read_csv("Default.tab", sep="\t")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(5)
# Out:
#   default student      balance        income
# 0      No      No   729.526495  44361.625074
# 1      No     Yes   817.180407  12106.134700
# 2      No      No  1073.549164  31767.138947
# 3      No      No   529.250605  35704.493935
# 4      No      No   785.655883  38463.495879

# %%
df.columns
# Out:
# Index(['default', 'student', 'balance', 'income'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   default  10000 non-null  object
#  1   student  10000 non-null  object
#  2   balance  10000 non-null  float64
#  3   income   10000 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 312.6+ KB

# %%
df["balance"].value_counts()
# Out:
# balance
# 0.000000       499
# 1092.530775      1
# 448.880656       1
# 506.625454       1
# 623.526119       1
#               ...
# 2202.462395      1
# 173.249172       1
# 770.015741       1
# 739.418018       1
# 1112.968401      1
# Name: count, Length: 9502, dtype: int64

# %%
df["income"].value_counts()
# Out:
# income
# 49861.003411    1
# 59441.309981    1
# 40656.951448    1
# 13684.789952    1
# 30697.245062    1
#                ..
# 38463.495879    1
# 35704.493935    1
# 31767.138947    1
# 12106.134700    1
# 44361.625074    1
# Name: count, Length: 10000, dtype: int64

# %%
df.describe()
# Out:
#             balance        income
# count  10000.000000  10000.000000
# mean     835.374886  33516.981876
# std      483.714985  13336.639563
# min        0.000000    771.967729
# 25%      481.731105  21340.462903
# 50%      823.636973  34552.644802
# 75%     1166.308386  43807.729272
# max     2654.322576  73554.233495

# %%
df.describe()["balance"]
# Out:
# count    10000.000000
# mean       835.374886
# std        483.714985
# min          0.000000
# 25%        481.731105
# 50%        823.636973
# 75%       1166.308386
# max       2654.322576
# Name: balance, dtype: float64

# %%
df.describe()["income"]
# Out:
# count    10000.000000
# mean     33516.981876
# std      13336.639563
# min        771.967729
# 25%      21340.462903
# 50%      34552.644802
# 75%      43807.729272
# max      73554.233495
# Name: income, dtype: float64

# %%
df["student"].value_counts()
# Out:
# student
# No     7056
# Yes    2944
# Name: count, dtype: int64

# %%
#Poit 7 of the exercise.
from pandas.plotting import scatter_matrix
attributes =["income", "balance"]
scatter_matrix(df[attributes], figsize=(12,8))
# Out:
# array([[<Axes: xlabel='income', ylabel='income'>,
#         <Axes: xlabel='balance', ylabel='income'>],
#        [<Axes: xlabel='income', ylabel='balance'>,
#         <Axes: xlabel='balance', ylabel='balance'>]], dtype=object)

# %%
#Point 8

sub_dataset=df[(df.student=="Yes")]
sub_dataset
# Out:
#      default student      balance        income
# 1         No     Yes   817.180407  12106.134700
# 5         No     Yes   919.588530   7491.558572
# 7         No     Yes   808.667504  17600.451344
# 10        No     Yes     0.000000  21871.073089
# 11        No     Yes  1220.583753  13268.562221
# ...      ...     ...          ...           ...
# 9980      No     Yes   770.015741  13684.789952
# 9986      No     Yes   401.332674  15332.017833
# 9989      No     Yes   999.281112  20013.350644
# 9994      No     Yes   172.412987  14955.941689
# 9999      No     Yes   200.922183  16862.952321
#
# [2944 rows x 4 columns]

# %%
#Point 9?
#df.loc[(df.balance>=0) & (df.income >=0)].value_counts()
subset = df[['balance', 'income']]
subset
# Out:
#           balance        income
# 0      729.526495  44361.625074
# 1      817.180407  12106.134700
# 2     1073.549164  31767.138947
# 3      529.250605  35704.493935
# 4      785.655883  38463.495879
# ...           ...           ...
# 9995   711.555020  52992.378914
# 9996   757.962918  19660.721768
# 9997   845.411989  58636.156984
# 9998  1569.009053  36669.112365
# 9999   200.922183  16862.952321
#
# [10000 rows x 2 columns]

# %%
#Point10
boxplot_balance_income=df[["balance", "income"]].boxplot()
boxplot_balance_income
# Out:
# <Axes: >

# %%
#Point 11
df[df["student"]=="Yes"]["income"].mean() - df[df["student"]=="No"]['income'].mean()
# Out:
# np.float64(-22061.72208173964)
